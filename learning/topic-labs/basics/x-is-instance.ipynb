# %% [markdown]
# # class Name
# Is is a dummy class for testing

# %%
class Name(str):
    pass

name = Name()

# %%
isinstance(name,Name)
# Out:
# True

# %%
isinstance(name,str)
# Out:
# True

# %%
isinstance("test",str)
# Out:
# True

# %%
isinstance("test",Name)
# Out:
# False

# %%
type("test")
# Out:
# str

# %%
type(name)
# Out:
# __main__.Name

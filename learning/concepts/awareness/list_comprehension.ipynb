# %%
[x for x in [(1,'a'),(2,'b'),(3,'c'),(4,'d')]]
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c'), (4, 'd')]

# %%
(x for x in [(1,'a'),(2,'b'),(3,'c'),(4,'d')])
# Out:
# <generator object <genexpr> at 0x7f19d3cd7d30>

# %%
gen = (x for x in [(1,'a'),(2,'b'),(3,'c'),(4,'d')])

# %%
next(gen)
# Out:
# (1, 'a')

# %%
next(gen)
# Out:
# (2, 'b')

# %%
def bar():
    print("bar")
    return 1

def foo():
    try:
        print("try")
        return bar()
    finally:
        print("finally")
        return 2

foo()
# Out:
# try
# bar
# finally
# 2

# %% [markdown]
# ## Testing jupyter

# %%
1+1
# Out:
# 2

# %%
import matplotlib.pyplot as plt
import random
random. randint(0,22)
# Out:
# 12

# %%
import soundfile as sf
import sounddevice as sd
import matplotlib.pyplot as plt

wav_file_name = "file_example_WAV_1MG.wav"
samples, samplerate = sf.read(wav_file_name)
samples= samples[:,0]
plt.plot(range(len(samples)), samples)
print(samplerate)
#print(type(samples[0]))
#print(samples.shape)
# Out:
# 44100

# %%
import random
import numpy

Y=numpy.random.normal(0,0.05)
print(Y)
# Out:
# 0.08501175191855888

# %%
noise = [numpy.random.normal(0,0.01)for i in range(len(samples))]
plt.plot(range(len(noise)), noise)

# %%
sound_with_noise = samples + noise
plt.plot(range(len(samples)), samples)

# %%
import sounddevice as sd
import math
#new_samples = samples + numpy.roll(samples,2000)
basic_freq = 400
ss= [math.cos((2*3.1415*(basic_freq + math.floor(i/441))) * i/44100) for i in range(1,44100*5)]
sin_signal = numpy.array(ss)
plt.plot(range(len(ss)),ss)
#sd.play(numpy.array(ss), 44100)
#sd.wait()

# %%
ss_fft = numpy.fft.fft(ss)
plt.plot(range(len(ss_fft)),ss_fft)

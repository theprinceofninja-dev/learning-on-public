# %%
import cv2
import os
import sys
import numpy as np
from pathlib import Path

#creates a figure with 10 (width) x 5 (height) inches
np.set_printoptions(threshold=sys.maxsize)

directory='/home/*******/Documents/OCR/'
index_you_want = -1#-1 for all
index_currently = 1
enable_img_show=False

for filename in os.listdir(directory):
    print(filename)
    if index_you_want!=-1:
        if index_you_want!=index_currently:
            index_currently+=1
            continue
        index_currently+=1
    
    if filename.endswith(".jpg") or  filename.endswith(".png"):
        f=os.path.join(directory, filename)
        print(f)
        # Read the original image
        img = cv2.imread(f)
        #img = cv2.resize(img, (320,320), interpolation = cv2.INTER_AREA)
        
        # Display original image
        if enable_img_show:
            #cv2.imshow('Original', img)
            cv2.imshow('Image',img)
            cv2.waitKey(0)

        # Convert to graycsale
        img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        if enable_img_show:
            #cv2.imshow('img_gray', img_gray)
            cv2.imshow('Image',img_gray)
            cv2.waitKey(0)

        # Blur the image for better edge detection
        #img_blur = cv2.GaussianBlur(img_gray, (1,1), 0)
        img_blur=img_gray
        if enable_img_show:
            #cv2.imshow('img_gray', img_gray)
            cv2.imshow('Image',img_blur)
            cv2.waitKey(0)
        #cv2.imshow('img_blur', img_blur)
        #cv2.waitKey(0)

        # Sobel Edge Detection
        sobelx = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=1, dy=0, ksize=5) # Sobel Edge Detection on the X axis
        #cv2.imshow('Sobel X', sobelx)
        #cv2.waitKey(0)

        sobely = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=0, dy=1, ksize=5) # Sobel Edge Detection on the Y axis
        #cv2.imshow('Sobel Y', sobely)
        #cv2.waitKey(0)

        sobelxy = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=1, dy=1, ksize=5) # Combined X and Y Sobel Edge Detection
        #cv2.imshow('Sobel X Y using Sobel() function', sobelxy)
        #cv2.waitKey(0)

        # Canny Edge Detection
        edges = cv2.Canny(image=img_blur, threshold1=100, threshold2=200) # Canny Edge Detection
        kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (1, 1))
        edges = cv2.dilate(edges, kernel)
    
        # Display Canny Edge Detection Image
        if enable_img_show:
            #cv2.imshow('Canny Edge Detection', edges)
            cv2.imshow('Image',edges)
            cv2.waitKey(0)
        
        #connected componenet #connected componenet #connected componenet #connected componenet #connected componenet
        
        (numLabels, labels, stats, centroids) = cv2.connectedComponentsWithStats(edges, 4 , cv2.CV_32S)
        #labels_colored = cv2.normalize(labels, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)
        
        #labels_colored = cv2.cvtColor(labels.astype("uint8"),cv2.COLOR_GRAY2BGR)
        #labels_colored = (labels_colored<-1).astype("uint8")
        #for i in range(0, numLabels):
        #   componentMask = (labels == i).astype("uint8") * 255
#            labels_colored[:,:,i%3] += componentMask-i
#            if enable_img_show:
#                print('labels_colored '+str(i))
#                cv2.imshow('labels_colored', labels_colored)
#                cv2.waitKey(0)
                
        areas = stats[:, cv2.CC_STAT_AREA]
        
        print('numLabels=',numLabels)
        print("len areas=",len(areas)," areas.shape=",areas.shape)
        print("labels.shape",labels.shape)
        
        #output = img.copy()
        output = cv2.cvtColor(img_blur.copy(), cv2.COLOR_GRAY2BGR)
        
        if enable_img_show:
                #cv2.imshow('output', output)
                cv2.imshow('Image',output)
                cv2.waitKey(0)
        
        img_width =  min(img.shape[0],img.shape[1])
        character_low_limit_area=(img_width/200)*(img_width/200)
        character_high_limit_area=(img_width/10)*(img_width/10)
        needed = sum(map(lambda x : x>character_low_limit_area and x<character_high_limit_area, stats[:,cv2.CC_STAT_AREA]))

        print("needed=",needed," numLabels=",numLabels)

        needed_counter=0
        
        # loop over the number of unique connected component labels######################Looooop
        for i in range(0, numLabels):
            
            #enable_img_show = i%15==0
            
            x = stats[i, cv2.CC_STAT_LEFT]
            y = stats[i, cv2.CC_STAT_TOP]
            w = stats[i, cv2.CC_STAT_WIDTH]
            h = stats[i, cv2.CC_STAT_HEIGHT]
            
            LENGTH=areas[i]
            AREA=w*h
            RATIO = LENGTH/AREA
            float_id = i/numLabels
            
            if RATIO<0.03:
                print('Processing ',i,' Discard due to RATIO=',RATIO)
                continue
                
            if not (areas[i]>character_low_limit_area and areas[i]<character_high_limit_area):
                #print('Processing ',i,' Discard:',areas[i])
                continue
            
            #print('Processing ',i)
            #print("->",needed_counter,"/",needed,"/area=",stats[i, cv2.CC_STAT_AREA])

            # construct a mask for the current connected component by
            # finding a pixels in the labels array that have the current
            # connected component ID

            labels_i = (labels == i).astype("uint8")
            #length = np.sum(sum(labels_i)) #this equals area[i]
            
            componentMask = labels_i * 255
            
            contours, hierarchy  = cv2.findContours(componentMask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
            #print(contours)
            cv2.drawContours(output, contours, -1, (255,255,255), 5)
            
            #componentMask = cv2.cvtColor(componentMask,cv2.COLOR_GRAY2BGR)
            
            edges_comononent = cv2.cvtColor(edges,cv2.COLOR_GRAY2BGR)
            edges_comononent[:,:,1]=componentMask
            
            cv2.putText(edges_comononent, str(needed_counter) , (x,y), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
            cv2.putText(edges_comononent, "length="+str(LENGTH)+", area="+str(AREA)+" rat: "+format(RATIO,".2f") , (30,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
            output[:,:,1] |= (labels_i * int(255*RATIO))
            
            if enable_img_show:
                cv2.imshow('componentMask', edges_comononent)
            #cv2.rectangle(output, (x, y),((x + w),(y + h)),(255, 255, 255), -1)
            #cv2.circle(output, (int(centroids[i][0]), int(centroids[i][1])), 1, (0, 255, 255), 5)    
            
            #output[:,:,2]+= (labels_i * int(255*RATIO))
            #output[:,:,1]+= (labels_i * int(255*RATIO))
            #output[:,:,0]+= (labels_i * int(255*RATIO))
            
            #cv2.putText(output, str(needed_counter) , (x,y+h), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)

            # show our output image and connected component mask
            #output = cv2.resize(output, (640,640), interpolation = cv2.INTER_AREA)
            
            cv2.rectangle(componentMask, (30, 20),(150,20),(255, 255, 255), -1)
            cv2.putText(output, 'output:'+str(i) , (30,20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, int(255*float_id),int((1-float_id)*255)), 2, cv2.LINE_AA)
            
            if enable_img_show:
                #cv2.imshow('output', output)
                cv2.imshow('Image',output)
                cv2.waitKey(0)

            #https://stackoverflow.com/questions/678236/how-to-get-the-filename-without-the-extension-from-a-path-in-python
            cv2.imwrite('/home/*******/Documents/OCR/compare_original_with_processed/{}{}.jpg'.format(Path(filename).stem,'_original'), img)
            cv2.imwrite('/home/*******/Documents/OCR/compare_original_with_processed/{}{}.jpg'.format(Path(filename).stem,'_processed'), output)

            needed_counter=needed_counter+1
        
        #output now is filled with whites
        output=output>250
        output=output.astype("uint8") *255
        print("output.shape=",output.shape)
        output=255-img*output
        cv2.imwrite('/home/*******/Documents/OCR/compare_original_with_processed/{}{}.jpg'.format(Path(filename).stem,'_final'), output)
        
        output = cv2.resize(output, (512,512), interpolation = cv2.INTER_AREA)
        if enable_img_show:
            #cv2.imshow('output', output)
            cv2.imshow('Image',output)
            cv2.waitKey(0)
            cv2.destroyAllWindows()
# Out:
# book_cover_perfect2.jpg
# /home/*******/Documents/OCR/book_cover_perfect2.jpg
# numLabels= 584
# len areas= 584  areas.shape= (584,)
# labels.shape (1000, 1100)
# needed= 306  numLabels= 584
# Processing  1  Discard due to RATIO= 0.006375306583214671
# Processing  90  Discard due to RATIO= 0.010115456625754108
# Processing  121  Discard due to RATIO= 0.018956419777213213
# Processing  153  Discard due to RATIO= 0.021951528993782516
# Processing  335  Discard due to RATIO= 0.011017252167694646
# Processing  347  Discard due to RATIO= 0.02680306905370844
# output.shape= (1000, 1100, 3)
# book_cover_arabic_3d.jpg
# /home/*******/Documents/OCR/book_cover_arabic_3d.jpg
# numLabels= 279
# len areas= 279  areas.shape= (279,)
# labels.shape (600, 600)
# needed= 98  numLabels= 279
# Processing  1  Discard due to RATIO= 0.02950778012354367
# Processing  211  Discard due to RATIO= 0.024196460816179127
# Processing  219  Discard due to RATIO= 0.024283559577677225
# output.shape= (600, 600, 3)
# face
# mix_color_hard.jpg
# /home/*******/Documents/OCR/mix_color_hard.jpg
# numLabels= 728
# len areas= 728  areas.shape= (728,)
# labels.shape (900, 600)
# needed= 294  numLabels= 728
# Processing  254  Discard due to RATIO= 0.008516006938968618
# Processing  255  Discard due to RATIO= 0.013750538549782764
# Processing  259  Discard due to RATIO= 0.013967641184434524
# Processing  271  Discard due to RATIO= 0.022979345155077373
# Processing  272  Discard due to RATIO= 0.024479166666666666
# Processing  348  Discard due to RATIO= 0.02502358692855305
# Processing  358  Discard due to RATIO= 0.01601533608054461
# output.shape= (900, 600, 3)
# book_cover_arabic_impoessible.webp
# code
# book_cover_impossible.jpg
# /home/*******/Documents/OCR/book_cover_impossible.jpg
# numLabels= 75
# len areas= 75  areas.shape= (75,)
# labels.shape (362, 236)
# needed= 67  numLabels= 75
# output.shape= (362, 236, 3)
# book_cover_arabic_3.png
# /home/*******/Documents/OCR/book_cover_arabic_3.png
# numLabels= 1775
# len areas= 1775  areas.shape= (1775,)
# labels.shape (622, 470)
# needed= 1192  numLabels= 1775
# Processing  2  Discard due to RATIO= 0.010850459212819874
# Processing  233  Discard due to RATIO= 0.025440555969223132
# Processing  248  Discard due to RATIO= 0.029019607843137254
# Processing  1086  Discard due to RATIO= 0.027723654178032624
# Processing  1179  Discard due to RATIO= 0.011000959385992964
# Processing  1569  Discard due to RATIO= 0.025571949602122016
# Processing  1574  Discard due to RATIO= 0.027611940298507463
# output.shape= (622, 470, 3)
# book_cover_english.jpg
# /home/*******/Documents/OCR/book_cover_english.jpg
# numLabels= 548
# len areas= 548  areas.shape= (548,)
# labels.shape (600, 392)
# needed= 373  numLabels= 548
# Processing  1  Discard due to RATIO= 0.029850746268656716
# Processing  2  Discard due to RATIO= 0.022002551020408163
# Processing  5  Discard due to RATIO= 0.029836929431033256
# Processing  6  Discard due to RATIO= 0.018766960975423307
# Processing  118  Discard due to RATIO= 0.015404238618524333
# Processing  482  Discard due to RATIO= 0.017429515158664623
# output.shape= (600, 392, 3)
# hard_fonts.jpg
# /home/*******/Documents/OCR/hard_fonts.jpg
# numLabels= 903
# len areas= 903  areas.shape= (903,)
# labels.shape (512, 342)
# needed= 702  numLabels= 903
# Processing  9  Discard due to RATIO= 0.018969555035128805
# Processing  16  Discard due to RATIO= 0.005139303863735029
# output.shape= (512, 342, 3)
# book_cover_perect3.jpeg
# compare_original_with_processed
# book_cover_perfect.jpg
# /home/*******/Documents/OCR/book_cover_perfect.jpg
# numLabels= 393
# len areas= 393  areas.shape= (393,)
# labels.shape (500, 387)
# needed= 269  numLabels= 393
# Processing  1  Discard due to RATIO= 0.009441789459710607
# Processing  2  Discard due to RATIO= 0.01559889591051064
# output.shape= (500, 387, 3)
# book_cover_hand_percect.jpg
# /home/*******/Documents/OCR/book_cover_hand_percect.jpg
# numLabels= 259
# len areas= 259  areas.shape= (259,)
# labels.shape (768, 547)
# needed= 216  numLabels= 259
# Processing  2  Discard due to RATIO= 0.012304652416022993
# Processing  6  Discard due to RATIO= 0.02316398677158171
# Processing  12  Discard due to RATIO= 0.013455705063389594
# Processing  53  Discard due to RATIO= 0.014947368421052631
# Processing  58  Discard due to RATIO= 0.0127960410038883
# Processing  110  Discard due to RATIO= 0.028911450279029114
# Processing  184  Discard due to RATIO= 0.027633101851851853
# output.shape= (768, 547, 3)
# outputs
# aa_2.png
# /home/*******/Documents/OCR/aa_2.png
# numLabels= 610
# len areas= 610  areas.shape= (610,)
# labels.shape (720, 1280)
# needed= 371  numLabels= 610
# Processing  167  Discard due to RATIO= 0.004532722373608976
# output.shape= (720, 1280, 3)
# 01_ocr_perfect.jpg
# /home/*******/Documents/OCR/01_ocr_perfect.jpg
# numLabels= 75
# len areas= 75  areas.shape= (75,)
# labels.shape (1800, 1273)
# needed= 67  numLabels= 75
# Processing  1  Discard due to RATIO= 0.0029040017225568514
# output.shape= (1800, 1273, 3)
# colored_hard_perfect.jpg
# /home/*******/Documents/OCR/colored_hard_perfect.jpg
# numLabels= 51
# len areas= 51  areas.shape= (51,)
# labels.shape (640, 434)
# needed= 44  numLabels= 51
# Processing  15  Discard due to RATIO= 0.010085902745819912
# output.shape= (640, 434, 3)
# aa_1.png
# /home/*******/Documents/OCR/aa_1.png
# numLabels= 768
# len areas= 768  areas.shape= (768,)
# labels.shape (720, 1280)
# needed= 576  numLabels= 768
# Processing  160  Discard due to RATIO= 0.004715401360958456
# output.shape= (720, 1280, 3)
# very_clear_but_Hard.jpg
# /home/*******/Documents/OCR/very_clear_but_Hard.jpg
# numLabels= 464
# len areas= 464  areas.shape= (464,)
# labels.shape (500, 500)
# needed= 284  numLabels= 464
# Processing  5  Discard due to RATIO= 0.0237865416436845
# Processing  11  Discard due to RATIO= 0.014739891738036545
# Processing  101  Discard due to RATIO= 0.017999064983637212
# Processing  108  Discard due to RATIO= 0.02728080808080808
# output.shape= (500, 500, 3)
# book_cover_arabic_2.jpg
# /home/*******/Documents/OCR/book_cover_arabic_2.jpg
# numLabels= 1186
# len areas= 1186  areas.shape= (1186,)
# labels.shape (894, 894)
# needed= 354  numLabels= 1186
# Processing  26  Discard due to RATIO= 0.023095364089735573
# output.shape= (894, 894, 3)
# hard_not_horizontal.jpg
# /home/*******/Documents/OCR/hard_not_horizontal.jpg
# numLabels= 370
# len areas= 370  areas.shape= (370,)
# labels.shape (319, 236)
# needed= 321  numLabels= 370
# output.shape= (319, 236, 3)
# book_cover_arabic_draw.png
# /home/*******/Documents/OCR/book_cover_arabic_draw.png
# numLabels= 1953
# len areas= 1953  areas.shape= (1953,)
# labels.shape (720, 1280)
# needed= 952  numLabels= 1953
# Processing  3  Discard due to RATIO= 0.00800358360064154
# Processing  131  Discard due to RATIO= 0.027454438565549678
# Processing  467  Discard due to RATIO= 0.00942838663633525
# Processing  1130  Discard due to RATIO= 0.02466879853814527
# Processing  1367  Discard due to RATIO= 0.0298783712321523
# output.shape= (720, 1280, 3)
# perfect_White.png
# /home/*******/Documents/OCR/perfect_White.png
# numLabels= 502
# len areas= 502  areas.shape= (502,)
# labels.shape (1234, 800)
# needed= 241  numLabels= 502
# output.shape= (1234, 800, 3)
# impossible_bold.jpg
# /home/*******/Documents/OCR/impossible_bold.jpg
# numLabels= 799
# len areas= 799  areas.shape= (799,)
# labels.shape (960, 960)
# needed= 307  numLabels= 799
# Processing  1  Discard due to RATIO= 0.008794323934653701
# Processing  219  Discard due to RATIO= 0.027437169251193924
# Processing  223  Discard due to RATIO= 0.025607638888888888
# Processing  626  Discard due to RATIO= 0.013127147766323025
# output.shape= (960, 960, 3)
# xyz.jpg
# /home/*******/Documents/OCR/xyz.jpg
# numLabels= 9
# len areas= 9  areas.shape= (9,)
# labels.shape (48, 70)
# needed= 5  numLabels= 9
# output.shape= (48, 70, 3)
# images
# book_cover_arabic_hard.jpg
# /home/*******/Documents/OCR/book_cover_arabic_hard.jpg
# numLabels= 302
# len areas= 302  areas.shape= (302,)
# labels.shape (434, 300)
# needed= 251  numLabels= 302
# Processing  15  Discard due to RATIO= 0.018930041152263374
# output.shape= (434, 300, 3)
# book_cover_perect3.jpg
# /home/*******/Documents/OCR/book_cover_perect3.jpg
# numLabels= 651
# len areas= 651  areas.shape= (651,)
# labels.shape (1000, 1000)
# needed= 172  numLabels= 651
# Processing  1  Discard due to RATIO= 0.005440043813468785
# Processing  67  Discard due to RATIO= 0.024367127308303777
# Processing  452  Discard due to RATIO= 0.01910760711039716
# Processing  455  Discard due to RATIO= 0.025945945945945945
# Processing  468  Discard due to RATIO= 0.017548076923076923
# Processing  471  Discard due to RATIO= 0.019624470018170807
# Processing  503  Discard due to RATIO= 0.027004741290455575
# Processing  549  Discard due to RATIO= 0.014537902388369679
# Processing  554  Discard due to RATIO= 0.01643153980752406
# Processing  570  Discard due to RATIO= 0.02153358474066787
# output.shape= (1000, 1000, 3)
# book_cover_mix_perfect.png
# /home/*******/Documents/OCR/book_cover_mix_perfect.png
# numLabels= 917
# len areas= 917  areas.shape= (917,)
# labels.shape (1000, 1000)
# needed= 244  numLabels= 917
# Processing  1  Discard due to RATIO= 0.006234548246928379
# Processing  58  Discard due to RATIO= 0.028144806101622087
# Processing  762  Discard due to RATIO= 0.012345679012345678
# Processing  763  Discard due to RATIO= 0.011585567692816948
# output.shape= (1000, 1000, 3)
# book_cover_mix_hard.jpg
# /home/*******/Documents/OCR/book_cover_mix_hard.jpg
# numLabels= 556
# len areas= 556  areas.shape= (556,)
# labels.shape (907, 600)
# needed= 328  numLabels= 556
# Processing  293  Discard due to RATIO= 0.021587625361210266
# Processing  386  Discard due to RATIO= 0.028330502305265712
# output.shape= (907, 600, 3)
# ocr_perfect_2.jpg
# /home/*******/Documents/OCR/ocr_perfect_2.jpg
# numLabels= 480
# len areas= 480  areas.shape= (480,)
# labels.shape (1200, 803)
# needed= 253  numLabels= 480
# output.shape= (1200, 803, 3)
# book_cover_perfect_hard.jpg
# /home/*******/Documents/OCR/book_cover_perfect_hard.jpg
# numLabels= 6349
# len areas= 6349  areas.shape= (6349,)
# labels.shape (1500, 1043)
# needed= 962  numLabels= 6349
# Processing  1  Discard due to RATIO= 0.020927217729489474
# Processing  5  Discard due to RATIO= 0.018932748538011697
# Processing  2445  Discard due to RATIO= 0.029365079365079365
# output.shape= (1500, 1043, 3)
# hand_written_hard.jpg
# /home/*******/Documents/OCR/hand_written_hard.jpg
# numLabels= 176
# len areas= 176  areas.shape= (176,)
# labels.shape (617, 617)
# needed= 142  numLabels= 176
# Processing  67  Discard due to RATIO= 0.019572224650349652
# Processing  103  Discard due to RATIO= 0.01928627302888895
# Processing  142  Discard due to RATIO= 0.022581229070504118
# output.shape= (617, 617, 3)
# book_cover_arabic_realistic.jpg
# /home/*******/Documents/OCR/book_cover_arabic_realistic.jpg
# numLabels= 828
# len areas= 828  areas.shape= (828,)
# labels.shape (731, 474)
# needed= 437  numLabels= 828
# Processing  537  Discard due to RATIO= 0.02606528621545307
# output.shape= (731, 474, 3)
# book_cover_tilted_perfect.jpg
# /home/*******/Documents/OCR/book_cover_tilted_perfect.jpg
# numLabels= 1109
# len areas= 1109  areas.shape= (1109,)
# labels.shape (1080, 1080)
# needed= 200  numLabels= 1109
# Processing  3  Discard due to RATIO= 0.017066267066267068
# Processing  5  Discard due to RATIO= 0.015365353972228546
# Processing  6  Discard due to RATIO= 0.005582401730977281
# Processing  52  Discard due to RATIO= 0.027856986181180085
# Processing  206  Discard due to RATIO= 0.016670084668795594
# Processing  233  Discard due to RATIO= 0.022144002851541614
# Processing  708  Discard due to RATIO= 0.019423558897243107
# Processing  859  Discard due to RATIO= 0.024592781858831046
# Processing  1012  Discard due to RATIO= 0.005227832512315271
# output.shape= (1080, 1080, 3)
